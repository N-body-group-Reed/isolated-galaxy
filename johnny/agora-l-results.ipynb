# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-l-data/agora-l.000025')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.g,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-l-data/agora-l.000025')

s.physical_units()

pynbody.analysis.angmom.sideon(s)

sph.image(s.g,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-l-data/agora-l.000050')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.g,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-l-data/agora-l.000025')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.s,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-l-data/agora-l.000050')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.s,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-l-data/agora-l.000125')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.g,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-l-data/agora-l.000125')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.s,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-l-data/agora-l.000125')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.dm,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-l-data/agora-l.000125')

s.physical_units()

pynbody.analysis.angmom.sideon(s)

sph.image(s.dm,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-l-data/agora-l.000150')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.s,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-l-data/agora-l.000400')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.s,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-l-data/agora-l.000400')

s.physical_units()

pynbody.analysis.angmom.sideon(s)

sph.image(s.s,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-l-data/agora-l.000400')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.g,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-l-data/agora-l.000400')

s.physical_units()

pynbody.analysis.angmom.sideon(s)

sph.image(s.g,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-l-data/agora-l.000400')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.dm,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-l-data/agora-l.000400')

s.physical_units()

pynbody.analysis.angmom.sideon(s)

sph.image(s.dm,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()
