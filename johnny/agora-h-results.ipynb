# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-h-data/agora-h.000050')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.g,qty="rho",units="g cm^-3",width=100,cmap="Greys")
# Out:
# /Users/johnny/anaconda3/lib/python3.6/site-packages/pynbody/snapshot/tipsy.py:130: RuntimeWarning: No readable param file in the run directory or parent directory: using defaults.
#   "No readable param file in the run directory or parent directory: using defaults.", RuntimeWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pynbody/plot/sph.py in image(sim, qty, width, resolution, units, log, vmin, vmax, av_z, filename, z_camera, clear, cmap, title, qtytitle, show_cbar, subplot, noplot, ret_im, fill_nan, fill_val, linthresh, **kwargs)
#     432             try:
# --> 433                 im[np.where(im == 0)] = abs(im[np.where(abs(im != 0))]).min()
#     434             except ValueError:
#
# ~/anaconda3/lib/python3.6/site-packages/pynbody/array.py in min(self, *args, **kwargs)
#     550     def min(self, *args, **kwargs):
# ...

# %%
import pynbody
import matplotlib.pylab as plt
from os import environ
# load the snapshot and set to physical units
s = pynbody.load('/Users/johnny/jupyter-notebks/agora-h-data/agora-h.000800')

# center on the largest halo and align the disk
pynbody.analysis.angmom.faceon(s)

# create a profile object for the stars
s.physical_units()
p = pynbody.analysis.profile.Profile(s,min=.01,max=250,type='log',ndim=3)
pg = pynbody.analysis.profile.Profile(s.g,min=.01,max=250,type='log',ndim=3)
ps = pynbody.analysis.profile.Profile(s.s,min=.01,max=250,type='log',ndim=3)
pd = pynbody.analysis.profile.Profile(s.d,min=.01,max=250,type='log',ndim=3)

# make the plot
plt.plot(p['rbins'],p['v_circ'],label='total')
plt.plot(pg['rbins'],pg['v_circ'],label='gas')
plt.plot(ps['rbins'],ps['v_circ'],label='stars')
plt.plot(pd['rbins'],pd['v_circ'],label='dm')

plt.xlabel('R [kpc]')
plt.ylabel(r'$v_c$ [km/s]')
plt.legend()
# Out:
# /Users/johnny/anaconda3/lib/python3.6/site-packages/pynbody/snapshot/tipsy.py:130: RuntimeWarning: No readable param file in the run directory or parent directory: using defaults.
#   "No readable param file in the run directory or parent directory: using defaults.", RuntimeWarning)
# pynbody.analysis.profile : Profile v_circ -- this routine assumes the disk is in the x-y plane
# pynbody.analysis.profile : Profile v_circ -- this routine assumes the disk is in the x-y plane
# pynbody.analysis.profile : Profile v_circ -- this routine assumes the disk is in the x-y plane
# pynbody.analysis.profile : Profile v_circ -- this routine assumes the disk is in the x-y plane

# %%
import pynbody
import matplotlib.pylab as plt
from os import environ
import pynbody.plot.sph as sph
# load the snapshot and set to physical units
s = pynbody.load('/Users/johnny/jupyter-notebks/agora-h-data/agora-h.000800')

# center on the largest halo and align the disk
pynbody.analysis.angmom.faceon(s)

# create a profile object for the stars
s.physical_units()
sph.image(s.g,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()
# Out:
# /Users/johnny/anaconda3/lib/python3.6/site-packages/pynbody/snapshot/tipsy.py:130: RuntimeWarning: No readable param file in the run directory or parent directory: using defaults.
#   "No readable param file in the run directory or parent directory: using defaults.", RuntimeWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pynbody/plot/sph.py in image(sim, qty, width, resolution, units, log, vmin, vmax, av_z, filename, z_camera, clear, cmap, title, qtytitle, show_cbar, subplot, noplot, ret_im, fill_nan, fill_val, linthresh, **kwargs)
#     432             try:
# --> 433                 im[np.where(im == 0)] = abs(im[np.where(abs(im != 0))]).min()
#     434             except ValueError:
#
# ~/anaconda3/lib/python3.6/site-packages/pynbody/array.py in min(self, *args, **kwargs)
#     550     def min(self, *args, **kwargs):
# ...

# %%
len(s.g)
# Out:
# 100000

# %%
len(s.dm)
# Out:
# 100000

# %%
len(s.s)
# Out:
# 112500

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-h-data/agora-h.000050')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.s,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()
# Out:
# /Users/johnny/anaconda3/lib/python3.6/site-packages/pynbody/snapshot/tipsy.py:130: RuntimeWarning: No readable param file in the run directory or parent directory: using defaults.
#   "No readable param file in the run directory or parent directory: using defaults.", RuntimeWarning)

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-h-data/agora-h.000100')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.s,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()
# Out:
# /Users/johnny/anaconda3/lib/python3.6/site-packages/pynbody/snapshot/tipsy.py:130: RuntimeWarning: No readable param file in the run directory or parent directory: using defaults.
#   "No readable param file in the run directory or parent directory: using defaults.", RuntimeWarning)

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-h-data/agora-h.000200')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.s,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()
# Out:
# /Users/johnny/anaconda3/lib/python3.6/site-packages/pynbody/snapshot/tipsy.py:130: RuntimeWarning: No readable param file in the run directory or parent directory: using defaults.
#   "No readable param file in the run directory or parent directory: using defaults.", RuntimeWarning)

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-h-data/agora-h.000300')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.s,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()
# Out:
# /Users/johnny/anaconda3/lib/python3.6/site-packages/pynbody/snapshot/tipsy.py:130: RuntimeWarning: No readable param file in the run directory or parent directory: using defaults.
#   "No readable param file in the run directory or parent directory: using defaults.", RuntimeWarning)

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-h-data/agora-h.000400')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.s,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()
# Out:
# /Users/johnny/anaconda3/lib/python3.6/site-packages/pynbody/snapshot/tipsy.py:130: RuntimeWarning: No readable param file in the run directory or parent directory: using defaults.
#   "No readable param file in the run directory or parent directory: using defaults.", RuntimeWarning)

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-h-data/agora-h.000600')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.s,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()
# Out:
# /Users/johnny/anaconda3/lib/python3.6/site-packages/pynbody/snapshot/tipsy.py:130: RuntimeWarning: No readable param file in the run directory or parent directory: using defaults.
#   "No readable param file in the run directory or parent directory: using defaults.", RuntimeWarning)

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-h-data/agora-h.000800')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.s,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()
# Out:
# /Users/johnny/anaconda3/lib/python3.6/site-packages/pynbody/snapshot/tipsy.py:130: RuntimeWarning: No readable param file in the run directory or parent directory: using defaults.
#   "No readable param file in the run directory or parent directory: using defaults.", RuntimeWarning)
