# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-u.000010')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.g,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-u.000020')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.g,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()
