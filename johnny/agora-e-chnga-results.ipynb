# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-e-chnga/agora-e-chnga.000800')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.g,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()
# Out:
# /Users/johnny/anaconda3/lib/python3.6/site-packages/pynbody/snapshot/tipsy.py:130: RuntimeWarning: No readable param file in the run directory or parent directory: using defaults.
#   "No readable param file in the run directory or parent directory: using defaults.", RuntimeWarning)

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-e-chnga/agora-e-chnga.000800')

s.physical_units()

pynbody.analysis.angmom.sideon(s)

sph.image(s.g,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()
# Out:
# /Users/johnny/anaconda3/lib/python3.6/site-packages/pynbody/snapshot/tipsy.py:130: RuntimeWarning: No readable param file in the run directory or parent directory: using defaults.
#   "No readable param file in the run directory or parent directory: using defaults.", RuntimeWarning)

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-e-chnga/agora-e-chnga.000600')

s.physical_units()

pynbody.analysis.angmom.faceon(s)

sph.image(s.g,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()
# Out:
# /Users/johnny/anaconda3/lib/python3.6/site-packages/pynbody/snapshot/tipsy.py:130: RuntimeWarning: No readable param file in the run directory or parent directory: using defaults.
#   "No readable param file in the run directory or parent directory: using defaults.", RuntimeWarning)

# %%
import pynbody

import pynbody.plot.sph as sph

import matplotlib.pylab as plt

s = pynbody.load('/Users/johnny/jupyter-notebks/agora-e-chnga/agora-e-chnga.000800')

s.physical_units()

pynbody.analysis.angmom.sideon(s)

sph.image(s.g,qty="rho",units="g cm^-3",width=100,cmap="Greys")
plt.show()
# Out:
# /Users/johnny/anaconda3/lib/python3.6/site-packages/pynbody/snapshot/tipsy.py:130: RuntimeWarning: No readable param file in the run directory or parent directory: using defaults.
#   "No readable param file in the run directory or parent directory: using defaults.", RuntimeWarning)
